# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

# %%
load_dotenv()
model = ChatOpenAI(model="gpt-4", temperature=0.5, max_tokens=1024)

# %%
result = model.invoke("Where did Chauri chaura incident took place")
print(result.content)
# Out:
# The Chauri Chaura incident took place in the Chauri Chaura town in the Gorakhpur district of the British Indian province of United Provinces (currently in Uttar Pradesh, India).
